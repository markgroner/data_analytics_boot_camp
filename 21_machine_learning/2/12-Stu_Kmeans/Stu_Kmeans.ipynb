# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
# Create dummy data
from sklearn.datasets.samples_generator import make_blobs

x_data, _ = make_blobs(n_samples=500, centers=6,
                       cluster_std=0.70, random_state=0)

# %%
# Plot and show scatter
plt.scatter(x_data[:, 0], x_data[:, 1])

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=12)

# %%
# Fit the model to the data
kmeans.fit(x_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=12, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(x_data)

# %%
# Plot the clusters
plt.scatter(x_data[:, 0], x_data[:, 1], c=predicted_clusters, s=50, cmap='Paired')

# %%
# Create a kmeans model using k = 6
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6)

# %%
# Fit the model to the data
kmeans.fit(x_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(x_data)

# %%
# Plot the clusters
plt.scatter(x_data[:, 0], x_data[:, 1], c=predicted_clusters, s=50, cmap='Paired')

# %%
# Bonus
# Print the cluster centers and cluster labls
# YOUR CODE HERE

# %%
# Plot the data using the cluster centers and cluster labls
plt.scatter(x_data[:, 0], x_data[:, 1], c=labels, s=50, cmap='Paired')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a07d62ba9079> in <module>()
#       1 # Plot the data using the cluster centers and cluster labls
# ----> 2 plt.scatter(x_data[:, 0], x_data[:, 1], c=labels, s=50, cmap='Paired')
#       3 plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
#
# NameError: name 'labels' is not defined
