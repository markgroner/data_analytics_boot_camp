# %%
import json
import requests
import pandas as pd
from config import api_key

# %%
city = 'Phoenix'
url = "http://api.openweathermap.org/data/2.5/forecast?"
params = {'q': city,
         'appid': api_key}

# %%
response = requests.get(url, params=params)
response_json = response.json()
response_json
# Out:
# {'city': {'coord': {'lat': 33.4484, 'lon': -112.0741},
#   'country': 'US',
#   'id': 5308655,
#   'name': 'Phoenix'},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 0},
#    'dt': 1510423200,
#    'dt_txt': '2017-11-11 18:00:00',
#    'main': {'grnd_level': 975.69,
#     'humidity': 46,
#     'pressure': 975.69,
#     'sea_level': 1028.2,
#     'temp': 298.04,
#     'temp_kf': 2.22,
#     'temp_max': 298.04,
#     'temp_min': 295.821},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 57.0015, 'speed': 1.81}},
#   {'clouds': {'all': 0},
#    'dt': 1510434000,
#    'dt_txt': '2017-11-11 21:00:00',
#    'main': {'grnd_level': 974.24,
#     'humidity': 39,
#     'pressure': 974.24,
#     'sea_level': 1026.41,
#     'temp': 300.42,
#     'temp_kf': 1.66,
#     'temp_max': 300.42,
#     'temp_min': 298.76},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 117.005, 'speed': 1.61}},
#   {'clouds': {'all': 0},
#    'dt': 1510444800,
#    'dt_txt': '2017-11-12 00:00:00',
#    'main': {'grnd_level': 974.06,
#     'humidity': 34,
#     'pressure': 974.06,
#     'sea_level': 1026.43,
#     'temp': 297.55,
#     'temp_kf': 1.11,
#     'temp_max': 297.55,
#     'temp_min': 296.439},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 135.501, 'speed': 0.56}},
#   {'clouds': {'all': 0},
#    'dt': 1510455600,
#    'dt_txt': '2017-11-12 03:00:00',
#    'main': {'grnd_level': 975.23,
#     'humidity': 54,
#     'pressure': 975.23,
#     'sea_level': 1028.3,
#     'temp': 288.78,
#     'temp_kf': 0.55,
#     'temp_max': 288.78,
#     'temp_min': 288.226},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 343.001, 'speed': 1.21}},
#   {'clouds': {'all': 0},
#    'dt': 1510466400,
#    'dt_txt': '2017-11-12 06:00:00',
#    'main': {'grnd_level': 975.83,
#     'humidity': 56,
#     'pressure': 975.83,
#     'sea_level': 1029.41,
#     'temp': 285.483,
#     'temp_kf': 0,
#     'temp_max': 285.483,
#     'temp_min': 285.483},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 9.50165, 'speed': 1.87}},
#   {'clouds': {'all': 0},
#    'dt': 1510477200,
#    'dt_txt': '2017-11-12 09:00:00',
#    'main': {'grnd_level': 976.38,
#     'humidity': 52,
#     'pressure': 976.38,
#     'sea_level': 1030.19,
#     'temp': 284.217,
#     'temp_kf': 0,
#     'temp_max': 284.217,
#     'temp_min': 284.217},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 21.0004, 'speed': 2.42}},
#   {'clouds': {'all': 8},
#    'dt': 1510488000,
#    'dt_txt': '2017-11-12 12:00:00',
#    'main': {'grnd_level': 976.73,
#     'humidity': 50,
#     'pressure': 976.73,
#     'sea_level': 1030.82,
#     'temp': 282.512,
#     'temp_kf': 0,
#     'temp_max': 282.512,
#     'temp_min': 282.512},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 10.5031, 'speed': 1.36}},
#   {'clouds': {'all': 0},
#    'dt': 1510498800,
#    'dt_txt': '2017-11-12 15:00:00',
#    'main': {'grnd_level': 977.76,
#     'humidity': 44,
#     'pressure': 977.76,
#     'sea_level': 1031.77,
#     'temp': 283.387,
#     'temp_kf': 0,
#     'temp_max': 283.387,
#     'temp_min': 283.387},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 13.5007, 'speed': 1.26}},
#   {'clouds': {'all': 32},
#    'dt': 1510509600,
#    'dt_txt': '2017-11-12 18:00:00',
#    'main': {'grnd_level': 978,
#     'humidity': 45,
#     'pressure': 978,
#     'sea_level': 1030.82,
#     'temp': 294.464,
#     'temp_kf': 0,
#     'temp_max': 294.464,
#     'temp_min': 294.464},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 31.0007, 'speed': 2.08}},
#   {'clouds': {'all': 32},
#    'dt': 1510520400,
#    'dt_txt': '2017-11-12 21:00:00',
#    'main': {'grnd_level': 976.37,
#     'humidity': 39,
#     'pressure': 976.37,
#     'sea_level': 1028.82,
#     'temp': 298.52,
#     'temp_kf': 0,
#     'temp_max': 298.52,
#     'temp_min': 298.52},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 342.007, 'speed': 1.81}},
#   {'clouds': {'all': 68},
#    'dt': 1510531200,
#    'dt_txt': '2017-11-13 00:00:00',
#    'main': {'grnd_level': 975.8,
#     'humidity': 37,
#     'pressure': 975.8,
#     'sea_level': 1028.37,
#     'temp': 296.405,
#     'temp_kf': 0,
#     'temp_max': 296.405,
#     'temp_min': 296.405},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 338.501, 'speed': 1.12}},
#   {'clouds': {'all': 76},
#    'dt': 1510542000,
#    'dt_txt': '2017-11-13 03:00:00',
#    'main': {'grnd_level': 976.32,
#     'humidity': 44,
#     'pressure': 976.32,
#     'sea_level': 1029.36,
#     'temp': 290.319,
#     'temp_kf': 0,
#     'temp_max': 290.319,
#     'temp_min': 290.319},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 301.51, 'speed': 1.2}},
#   {'clouds': {'all': 80},
#    'dt': 1510552800,
#    'dt_txt': '2017-11-13 06:00:00',
#    'main': {'grnd_level': 976.47,
#     'humidity': 43,
#     'pressure': 976.47,
#     'sea_level': 1029.76,
#     'temp': 288.182,
#     'temp_kf': 0,
#     'temp_max': 288.182,
#     'temp_min': 288.182},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 325.504, 'speed': 0.86}},
#   {'clouds': {'all': 64},
#    'dt': 1510563600,
#    'dt_txt': '2017-11-13 09:00:00',
#    'main': {'grnd_level': 976.32,
#     'humidity': 42,
#     'pressure': 976.32,
#     'sea_level': 1029.73,
#     'temp': 288.088,
#     'temp_kf': 0,
#     'temp_max': 288.088,
#     'temp_min': 288.088},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 348.5, 'speed': 0.46}},
#   {'clouds': {'all': 76},
#    'dt': 1510574400,
#    'dt_txt': '2017-11-13 12:00:00',
#    'main': {'grnd_level': 976.23,
#     'humidity': 44,
#     'pressure': 976.23,
#     'sea_level': 1029.78,
#     'temp': 287.096,
#     'temp_kf': 0,
#     'temp_max': 287.096,
#     'temp_min': 287.096},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 85.0016, 'speed': 1.01}},
#   {'clouds': {'all': 68},
#    'dt': 1510585200,
#    'dt_txt': '2017-11-13 15:00:00',
#    'main': {'grnd_level': 977.34,
#     'humidity': 47,
#     'pressure': 977.34,
#     'sea_level': 1030.85,
#     'temp': 287.295,
#     'temp_kf': 0,
#     'temp_max': 287.295,
#     'temp_min': 287.295},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 81.0014, 'speed': 1.15}},
#   {'clouds': {'all': 56},
#    'dt': 1510596000,
#    'dt_txt': '2017-11-13 18:00:00',
#    'main': {'grnd_level': 978.17,
#     'humidity': 49,
#     'pressure': 978.17,
#     'sea_level': 1030.79,
#     'temp': 295.726,
#     'temp_kf': 0,
#     'temp_max': 295.726,
#     'temp_min': 295.726},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 68.5009, 'speed': 1.92}},
#   {'clouds': {'all': 80},
#    'dt': 1510606800,
#    'dt_txt': '2017-11-13 21:00:00',
#    'main': {'grnd_level': 976.45,
#     'humidity': 44,
#     'pressure': 976.45,
#     'sea_level': 1028.83,
#     'temp': 297.392,
#     'temp_kf': 0,
#     'temp_max': 297.392,
#     'temp_min': 297.392},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 140.502, 'speed': 1.74}},
#   {'clouds': {'all': 12},
#    'dt': 1510617600,
#    'dt_txt': '2017-11-14 00:00:00',
#    'main': {'grnd_level': 975.92,
#     'humidity': 41,
#     'pressure': 975.92,
#     'sea_level': 1028.45,
#     'temp': 295.762,
#     'temp_kf': 0,
#     'temp_max': 295.762,
#     'temp_min': 295.762},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 210.009, 'speed': 0.28}},
#   {'clouds': {'all': 80},
#    'dt': 1510628400,
#    'dt_txt': '2017-11-14 03:00:00',
#    'main': {'grnd_level': 976.27,
#     'humidity': 58,
#     'pressure': 976.27,
#     'sea_level': 1029.21,
#     'temp': 289.561,
#     'temp_kf': 0,
#     'temp_max': 289.561,
#     'temp_min': 289.561},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 344.504, 'speed': 1.22}},
#   {'clouds': {'all': 24},
#    'dt': 1510639200,
#    'dt_txt': '2017-11-14 06:00:00',
#    'main': {'grnd_level': 976.15,
#     'humidity': 57,
#     'pressure': 976.15,
#     'sea_level': 1029.45,
#     'temp': 287.404,
#     'temp_kf': 0,
#     'temp_max': 287.404,
#     'temp_min': 287.404},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 16.5021, 'speed': 1.47}},
#   {'clouds': {'all': 0},
#    'dt': 1510650000,
#    'dt_txt': '2017-11-14 09:00:00',
#    'main': {'grnd_level': 975.94,
#     'humidity': 62,
#     'pressure': 975.94,
#     'sea_level': 1029.37,
#     'temp': 286.12,
#     'temp_kf': 0,
#     'temp_max': 286.12,
#     'temp_min': 286.12},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 43.5007, 'speed': 1.69}},
#   {'clouds': {'all': 0},
#    'dt': 1510660800,
#    'dt_txt': '2017-11-14 12:00:00',
#    'main': {'grnd_level': 975.79,
#     'humidity': 65,
#     'pressure': 975.79,
#     'sea_level': 1029.4,
#     'temp': 284.929,
#     'temp_kf': 0,
#     'temp_max': 284.929,
#     'temp_min': 284.929},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 67.0001, 'speed': 1.68}},
#   {'clouds': {'all': 8},
#    'dt': 1510671600,
#    'dt_txt': '2017-11-14 15:00:00',
#    'main': {'grnd_level': 976.27,
#     'humidity': 64,
#     'pressure': 976.27,
#     'sea_level': 1029.8,
#     'temp': 285.218,
#     'temp_kf': 0,
#     'temp_max': 285.218,
#     'temp_min': 285.218},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 67.5038, 'speed': 1.26}},
#   {'clouds': {'all': 0},
#    'dt': 1510682400,
#    'dt_txt': '2017-11-14 18:00:00',
#    'main': {'grnd_level': 976.44,
#     'humidity': 53,
#     'pressure': 976.44,
#     'sea_level': 1029.01,
#     'temp': 296.231,
#     'temp_kf': 0,
#     'temp_max': 296.231,
#     'temp_min': 296.231},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 84.0005, 'speed': 1.81}},
#   {'clouds': {'all': 0},
#    'dt': 1510693200,
#    'dt_txt': '2017-11-14 21:00:00',
#    'main': {'grnd_level': 974.37,
#     'humidity': 47,
#     'pressure': 974.37,
#     'sea_level': 1026.59,
#     'temp': 298.824,
#     'temp_kf': 0,
#     'temp_max': 298.824,
#     'temp_min': 298.824},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 163.504, 'speed': 1.86}},
#   {'clouds': {'all': 8},
#    'dt': 1510704000,
#    'dt_txt': '2017-11-15 00:00:00',
#    'main': {'grnd_level': 973.45,
#     'humidity': 42,
#     'pressure': 973.45,
#     'sea_level': 1025.83,
#     'temp': 296.499,
#     'temp_kf': 0,
#     'temp_max': 296.499,
#     'temp_min': 296.499},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 231.002, 'speed': 1.11}},
#   {'clouds': {'all': 20},
#    'dt': 1510714800,
#    'dt_txt': '2017-11-15 03:00:00',
#    'main': {'grnd_level': 973.69,
#     'humidity': 70,
#     'pressure': 973.69,
#     'sea_level': 1026.45,
#     'temp': 288.506,
#     'temp_kf': 0,
#     'temp_max': 288.506,
#     'temp_min': 288.506},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 263.501, 'speed': 1.2}},
#   {'clouds': {'all': 12},
#    'dt': 1510725600,
#    'dt_txt': '2017-11-15 06:00:00',
#    'main': {'grnd_level': 973.78,
#     'humidity': 78,
#     'pressure': 973.78,
#     'sea_level': 1026.97,
#     'temp': 285.459,
#     'temp_kf': 0,
#     'temp_max': 285.459,
#     'temp_min': 285.459},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 342.503, 'speed': 1.01}},
#   {'clouds': {'all': 8},
#    'dt': 1510736400,
#    'dt_txt': '2017-11-15 09:00:00',
#    'main': {'grnd_level': 973.66,
#     'humidity': 75,
#     'pressure': 973.66,
#     'sea_level': 1026.96,
#     'temp': 284.417,
#     'temp_kf': 0,
#     'temp_max': 284.417,
#     'temp_min': 284.417},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 42.5009, 'speed': 1.58}},
#   {'clouds': {'all': 12},
#    'dt': 1510747200,
#    'dt_txt': '2017-11-15 12:00:00',
#    'main': {'grnd_level': 973.37,
#     'humidity': 74,
#     'pressure': 973.37,
#     'sea_level': 1026.83,
#     'temp': 283.679,
#     'temp_kf': 0,
#     'temp_max': 283.679,
#     'temp_min': 283.679},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 60.0025, 'speed': 1.94}},
#   {'clouds': {'all': 48},
#    'dt': 1510758000,
#    'dt_txt': '2017-11-15 15:00:00',
#    'main': {'grnd_level': 974.32,
#     'humidity': 64,
#     'pressure': 974.32,
#     'sea_level': 1027.73,
#     'temp': 284.884,
#     'temp_kf': 0,
#     'temp_max': 284.884,
#     'temp_min': 284.884},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 54.5041, 'speed': 1.91}},
#   {'clouds': {'all': 88},
#    'dt': 1510768800,
#    'dt_txt': '2017-11-15 18:00:00',
#    'main': {'grnd_level': 974.95,
#     'humidity': 52,
#     'pressure': 974.95,
#     'sea_level': 1027.57,
#     'temp': 294.215,
#     'temp_kf': 0,
#     'temp_max': 294.215,
#     'temp_min': 294.215},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 84.0016, 'speed': 1.72}},
#   {'clouds': {'all': 44},
#    'dt': 1510779600,
#    'dt_txt': '2017-11-15 21:00:00',
#    'main': {'grnd_level': 973.24,
#     'humidity': 51,
#     'pressure': 973.24,
#     'sea_level': 1025.49,
#     'temp': 296.36,
#     'temp_kf': 0,
#     'temp_max': 296.36,
#     'temp_min': 296.36},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 147.503, 'speed': 1.88}},
#   {'clouds': {'all': 8},
#    'dt': 1510790400,
#    'dt_txt': '2017-11-16 00:00:00',
#    'main': {'grnd_level': 972.48,
#     'humidity': 47,
#     'pressure': 972.48,
#     'sea_level': 1024.78,
#     'temp': 294.607,
#     'temp_kf': 0,
#     'temp_max': 294.607,
#     'temp_min': 294.607},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 169.003, 'speed': 1.23}},
#   {'clouds': {'all': 0},
#    'dt': 1510801200,
#    'dt_txt': '2017-11-16 03:00:00',
#    'main': {'grnd_level': 973.15,
#     'humidity': 75,
#     'pressure': 973.15,
#     'sea_level': 1026.02,
#     'temp': 287.346,
#     'temp_kf': 0,
#     'temp_max': 287.346,
#     'temp_min': 287.346},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 217.502, 'speed': 1.34}},
#   {'clouds': {'all': 0},
#    'dt': 1510812000,
#    'dt_txt': '2017-11-16 06:00:00',
#    'main': {'grnd_level': 973.7,
#     'humidity': 82,
#     'pressure': 973.7,
#     'sea_level': 1026.75,
#     'temp': 284.333,
#     'temp_kf': 0,
#     'temp_max': 284.333,
#     'temp_min': 284.333},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 334.501, 'speed': 1.17}},
#   {'clouds': {'all': 0},
#    'dt': 1510822800,
#    'dt_txt': '2017-11-16 09:00:00',
#    'main': {'grnd_level': 973.08,
#     'humidity': 79,
#     'pressure': 973.08,
#     'sea_level': 1026.45,
#     'temp': 283.546,
#     'temp_kf': 0,
#     'temp_max': 283.546,
#     'temp_min': 283.546},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 69.5003, 'speed': 1.71}},
#   {'clouds': {'all': 0},
#    'dt': 1510833600,
#    'dt_txt': '2017-11-16 12:00:00',
#    'main': {'grnd_level': 972.82,
#     'humidity': 78,
#     'pressure': 972.82,
#     'sea_level': 1026.39,
#     'temp': 282.748,
#     'temp_kf': 0,
#     'temp_max': 282.748,
#     'temp_min': 282.748},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 70.5008, 'speed': 1.31}},
#   {'clouds': {'all': 0},
#    'dt': 1510844400,
#    'dt_txt': '2017-11-16 15:00:00',
#    'main': {'grnd_level': 973.97,
#     'humidity': 78,
#     'pressure': 973.97,
#     'sea_level': 1027.55,
#     'temp': 283.263,
#     'temp_kf': 0,
#     'temp_max': 283.263,
#     'temp_min': 283.263},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 47.5042, 'speed': 1.32}}],
#  'message': 0.1685}
